# %%
import pandas as pd
import os
import numpy as np
import plotly.express as px

# %%
cdi = os.path.join('Resources', '')
cdi_df = pd.read_csv(cdi)
cdi_df.head(1000)
# Out:
# /Users/slimykid/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      YearStart  YearEnd LocationAbbr LocationDesc              DataSource  \
# 0         2011     2011           AK       Alaska                    NVSS
# 1         2014     2014           AK       Alaska                    NVSS
# 2         2017     2017           AK       Alaska               SEDD; SID
# 3         2017     2017           AL      Alabama                    NVSS
# 4         2015     2015           AL      Alabama               SEDD; SID
# ..         ...      ...          ...          ...                     ...
# 995       2001     2001           AL      Alabama         NVSS, Mortality
# 996       2015     2015           AK       Alaska               SEDD; SID
# ...

# %%
health_df['une_poverty']
# Out:
# 291

# %% [markdown]
# Does health spending impact life expectency ? corr
# Does the rate of change from 2000-2016 in Current health expenditure (CHE) impact life expectency and adult mortality? corr
# How does the life expectancy after age 60 compare to the life expectancy at birth?
#
# look at specific year for specific columns that have missing data (ex 2016)
#
# explain countries and regions// alc consumption between regions
#
# alc affect over years on BMI, Life expect., Life expect60<, PPP, infant mort, and age 1-4 mort
# compare re
#
#
# alc use increases with increased gni
#
# rate of change from 2000-2016 alc use
#
# NGO non profit sect of WHO
